# %% [markdown]
# <a href="https://colab.research.google.com/github/Vatsal1710/session1/blob/main/2_1_Introduction_to_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### What is data visualization?
#  Data Visualization is the presentation of data in pictorial or graphical format.
# ### OR
# Data visualization which is the process of translating the numbers, text, or large data sets into various types of graphs such as histograms, maps, bar plots, pie charts, etc.
# ### Why Data Visualization?
# - Human brain can process information easily when it is in pictorial or graphical form.
# - Data Visualization allows us to quickly interpret data and adjust different variables to see their effect
# - Find insights in data

# %% [markdown]
# Data visualization is one of the important skills that data scientists are expected to have. Visualization techniques can be used to understand and address the majority of business challenges. Exploratory Data Analysis (EDA) and Graphical Plots are the two main components of visualization. Effective visualization helps users in understanding data trends and solving business problems more efficiently. Another advantage of visualization is that it reduces complex data to a more readable manner.Visualization is the most effective communication tool for analyzing and interpreting data. It allows customers to quickly interpret vast amounts of data. Trends, correlations, patterns, distributions, and so on can all be better understood through data visualization.

# %% [markdown]
#  ### Python has many libraries for data visualization; a few of the most prominent graphic libraries are:
#  Matplotlib,
#  Seaborn,
#  Pandas visualization and
#  Plotly

# %% [markdown]
# ### What is Matplotlib?
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
# Matplotlib is an open-source drawing library that supports various drawing types.
# You can generate plots, histograms, bar charts, and other types of charts with just a few lines of code.
# It can be used in python scripts, shell, web application servers and other graphical user interface toolkits.

# %% [markdown]
# ### John Hunter founded the Matplotlib project in 2002. Matplotlib was created during post-doctoral study in Neurobiology to show Electrocorticography (ECoG) data from epileptic patients.

# %% [markdown]
# ### Why is Matplotlib so Popular?

# %% [markdown]
# 1. For beginners, it's simple and straightforward.
# 2. It's open-source and free.
# 3. Matplotlib is a highly customized and robust.
# 4. Matplotlib is good at working with data frames and arrays. Figures and axes are treated as objects.
# 5. Those who have used Matlab or other graph plotting tools before will find Matplotlib to be easy to use.

# %% [markdown]
# ### Getting Started With Pyplot API

# %% [markdown]
# Pyplot is an Application Programming Interface (API) that consists of functions/ methods which help process data for visualization.
# The plot is quick when it comes to generating visual graphs.
# In addition, its similarities with Matlab make working easy for individuals who have prior experience working with MATLAB and vice versa.

# %% [markdown]
# ### How can one work with Pyplot in Matplotlib?

# %% [markdown]
# In order to be able to access pyplot methods, one needs to import it in their python file.
# This can be done by including the below line at the top of one’s python file:

# %% [markdown]
# from matplotlib import pyplot as plt
# ###                    OR
# import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(1,2,'g*') ### By Default, the plot(x,y) method draw a line between points. To draw point we have to pass format.
plt.show()

# %%
plt.plot([2,3,4],[4,9,16],'bo--')
plt.show()

# %%
plt.plot([2,3,4],[4,9,16]) ###Plot y versus x as lines and/or markers.
plt.show()

# %%
### If you are passing one array only

# %%
plt.plot([2,5,8,4,1,9],'ro--') ### plot y using x as index array 0..N-1
plt.show()

# %%
x=[1,2,3,4]
y=[1,4,9,16]
plt.plot(x,y,'ro-')
plt.grid(True)
plt.show()

# %%
plt.plot(x,y,color='green',linewidth=5,linestyle='dotted',marker='+',markersize=20)
plt.show()

# %%
plt.plot(x,y,'go:',linewidth=5,markersize=10)
plt.show()

# %% [markdown]
# Our graph have no label and no descriptive information.
# Let us now see how we can add a title, as well as the x-axis and y-axis names, using the title(), xlabel(), and ylabel() methods, respectively.

# %%
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title(" Info",loc='left')
plt.plot(x,y)
plt.show()

# %%
x=[1,2,3,4]
y=[1,4,9,16]
labels = ['Frogs', 'Hogs', 'Bogs', 'Slogs']
plt.plot(x,y)
plt.xticks(x,labels,rotation=30)
plt.yticks(rotation=30)
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title(" Info",loc='center')
plt.show()

# %% [markdown]
# #### In the above graph, the horizontal axis is labeled as ‘X-axis’ and the vertical axis is labeled as ‘Y-axis’, and the title is displayed as ‘info’.

# %%
###plot() function accept basically three parameters in order (x,y,fmt)
###format string is a short hand combination of {color}{marker}{line}.
#plt.plot(x,y,'go')
#plt.plot(y,x,'b*')
#plt.plot(x,y,'bD')
plt.plot(x,y,'--r',marker='o', markersize=10)
plt.grid(False)
plt.show()

# %% [markdown]
# ### How to add style to a graph using python matplotlib.

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
angles=np.linspace(-np.pi,+np.pi)
print(angles)
sin=np.sin(2*angles)
print(sin)
plt.plot(angles,sin)
plt.grid()
plt.show()
# Out:
# [-3.14159265 -3.01336438 -2.88513611 -2.75690784 -2.62867957 -2.5004513
#  -2.37222302 -2.24399475 -2.11576648 -1.98753821 -1.85930994 -1.73108167
#  -1.60285339 -1.47462512 -1.34639685 -1.21816858 -1.08994031 -0.96171204
#  -0.83348377 -0.70525549 -0.57702722 -0.44879895 -0.32057068 -0.19234241
#  -0.06411414  0.06411414  0.19234241  0.32057068  0.44879895  0.57702722
#   0.70525549  0.83348377  0.96171204  1.08994031  1.21816858  1.34639685
#   1.47462512  1.60285339  1.73108167  1.85930994  1.98753821  2.11576648
#   2.24399475  2.37222302  2.5004513   2.62867957  2.75690784  2.88513611
#   3.01336438  3.14159265]
# [ 2.44929360e-16  2.53654584e-01  4.90717552e-01  6.95682551e-01
#   8.55142763e-01  9.58667853e-01  9.99486216e-01  9.74927912e-01
#   8.86599306e-01  7.40277997e-01  5.45534901e-01  3.15108218e-01
#   6.40702200e-02 -1.91158629e-01 -4.33883739e-01 -6.48228395e-01
#  -8.20172255e-01 -9.38468422e-01 -9.95379113e-01 -9.87181783e-01
# ...

# %% [markdown]
# ### Subplot
# A subplot() function can be called to plot multiple plots in the same figure.

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.subplot(1,2,1)
plt.plot([1,4])
plt.subplot(1,2,2)
plt.plot([2,2])
plt.show()
